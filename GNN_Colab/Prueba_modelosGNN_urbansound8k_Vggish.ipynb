# %% [markdown]
# # Librarias

# %%
import torch

def format_pytorch_version(version):
  return version.split('+')[0]

TORCH_version = torch.__version__
TORCH = format_pytorch_version(TORCH_version)

def format_cuda_version(version):
  return 'cu' + version.replace('.', '')

CUDA_version = torch.version.cuda
CUDA = format_cuda_version(CUDA_version)

# !pip install torch-scatter     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse      -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-cluster     -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.1+cu113.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_scatter-2.1.0%2Bpt112cu113-cp37-cp37m-linux_x86_64.whl (8.9 MB)
#      |████████████████████████████████| 8.9 MB 35.7 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.1.0+pt112cu113
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.1+cu113.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_sparse-0.6.15%2Bpt112cu113-cp37-cp37m-linux_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 41.3 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse) (1.21.6)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.15+pt112cu113
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.1+cu113.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_cluster-1.6.0%2Bpt112cu113-cp37-cp37m-linux_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 37.7 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-cluster) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-cluster) (1.21.6)
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0+pt112cu113
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.12.1+cu113.html
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_spline_conv-1.2.1%2Bpt112cu113-cp37-cp37m-linux_x86_64.whl (722 kB)
#      |████████████████████████████████| 722 kB 33.9 MB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1+pt112cu113
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.1.0.post1.tar.gz (467 kB)
#      |████████████████████████████████| 467 kB 31.3 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.1.0.post1-py3-none-any.whl size=689859 sha256=c487c6ed2743856b93b7442d1fcdabb0704c719d192f790c91da7e9d6e3200c6
#   Stored in directory: /root/.cache/pip/wheels/d1/cb/43/f7f2e472de4d7cff31bceddadc36d634e1e545fbc17961c282
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.1.0.post1

# %%
import random
import numpy as np
import pandas as pd
import time

import matplotlib.pyplot as plt


import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# # Colab-drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataframe

# %%
df = pd.read_csv("/content/drive/MyDrive/Teoría de grafos/urban/UrbanSound8K.csv")
df
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 0       100032-3-0-0.wav  100032    0.000000    0.317551         1     5
# 1     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 2     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 3     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 4     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8727     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8728     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8729     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8730     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8731     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           3          dog_bark
# 1           2  children_playing
# 2           2  children_playing
# 3           2  children_playing
# 4           2  children_playing
# ...       ...               ...
# 8727        1          car_horn
# 8728        1          car_horn
# 8729        1          car_horn
# 8730        1          car_horn
# 8731        1          car_horn
#
# [8732 rows x 8 columns]

# %%
df = df[(df.end - df.start) > 0.96*2]
df.reset_index(drop=True, inplace=True)
df
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 0     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 1     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 2     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 3     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# 4     100263-2-0-143.wav  100263   71.500000   75.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 7775     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 7776     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 7777     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 7778     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 7779     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           2  children_playing
# 1           2  children_playing
# 2           2  children_playing
# 3           2  children_playing
# 4           2  children_playing
# ...       ...               ...
# 7775        1          car_horn
# 7776        1          car_horn
# 7777        1          car_horn
# 7778        1          car_horn
# 7779        1          car_horn
#
# [7780 rows x 8 columns]

# %% [markdown]
# # Datos

# %% [markdown]
# Los datos usados son del dataset urbansound8k y sus audios fueron caracterizados con el modelo preentrenado Vggish para luego guardar dichas caracteristicas y etiquetas en un archivo con extencion .h5py

# %%
import h5py

# %%
TF = h5py.File('TF_vggish.hdf5', 'r')

# %%
TF.keys()
# Out:
# <KeysViewHDF5 ['features', 'labels']>

# %%
X = TF['features']
Y = TF['labels']

# %%
X.dtype
# Out:
# dtype('<f4')

# %%
type(X)
# Out:
# h5py._hl.dataset.Dataset

# %%
X_tensor = torch.tensor(X)
Y_tensor = torch.tensor(Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   """Entry point for launching an IPython kernel.

# %%
X_tensor.shape
# Out:
# torch.Size([7780, 128])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# # Creacion de grafos

# %%
from torch_geometric.data import Data
from torch_geometric.nn import knn_graph

# %%
def CrossVal(df, idxtest, idxval):
    df.reset_index(drop=True, inplace=True)
    df2 = df.copy()
    
    Idx_test = df.index[df.fold == idxtest]

    df2.drop(Idx_test, inplace=True)

    Idx_val = df.index[df.fold == idxval]

    df2.drop(Idx_val, inplace=True)
    
    Idx_train = df2.index
    
    return Idx_train, Idx_test, Idx_val

# %%
def graph(X_tensor, Y_tensor, Idx_train, Idx_test, Idx_val, val_k):

  x = X_tensor

#Labels nodes

  y = Y_tensor

#Datos de entrenamiento y test

  train_mask = Idx_train
  train_mask = torch.tensor(train_mask)

  test_mask = Idx_test
  test_mask = torch.tensor(test_mask)

  val_mask = Idx_val
  val_mask = torch.tensor(val_mask)

#Se crea las conexines de los nodos

  edge_index = knn_graph(x, k=val_k, batch=y, loop=False)


  #Creacion del grafo 

  data = Data(x=x, edge_index= edge_index, y = y , train_mask = train_mask, test_mask = test_mask, val_mask = val_mask)# edge_index tensor que define los nodos de origen y desdetino.
  data = data.to(device)
  return data

# %% [markdown]
# # Train Test Val

# %%
def accuracy(pred_y, y):
    
    return ((pred_y == y).sum() / len(y)).item()

def test(model, data, mask):
    
    model.eval()
    out = model(data.x, data.edge_index)
    acc = accuracy(torch.argmax(out, dim = 1)[mask], data.y[mask])
    return acc

def train(model, data, epoch):
    
    f_loss = nn.CrossEntropyLoss()
    optimizer = model.optimizer
    epochs = epoch

    model.train()
    for epoch in range(epochs+1):
        
        optimizer.zero_grad()
        out = model(data.x, data.edge_index)
        loss = f_loss(out[data.train_mask], data.y[data.train_mask])
        acc = accuracy(torch.argmax(out, dim = 1)[data.train_mask], data.y[data.train_mask])
        loss.backward()
        optimizer.step()

        
        
        val_acc = test(model, data, data.val_mask)

        
          #if(epoch % 10 == 0):
            #print(f'Epoch {epoch:>3} | Train Loss: {loss:.3f} | Train Acc: '
                  #f'{acc*100:>6.2f}% |' f'Val Acc: {val_acc*100:.2f}%')
          
    return model

# %% [markdown]
# # Modelos

# %%
from torch.nn import Linear, Dropout
from torch_geometric.nn import GCNConv, GATv2Conv, SAGEConv

# %% [markdown]
# ## GAT

# %%
class GAT(torch.nn.Module):
  def __init__(self, dim_in, dim_h, dim_out, heads=10):
    super().__init__()
    self.gat1 = GATv2Conv(dim_in, dim_h, heads=heads)
    self.gat2 = GATv2Conv(dim_h*heads, dim_out, heads=1)
    self.optimizer = torch.optim.Adam(self.parameters(),
                                      lr=0.001,
                                      weight_decay=5e-4)

  def forward(self, x, edge_index):
    h = F.dropout(x, p=0.5, training=self.training)
    h = self.gat1(h, edge_index)
    h = F.relu(h)
    h = F.dropout(h, p=0.5, training=self.training)
    h = self.gat2(h, edge_index)
  
    return h

# %% [markdown]
# ## GCN

# %%
class GCN(torch.nn.Module):
  def __init__(self, dim_in, dim_h, dim_out):
    super().__init__()
    self.gcn1 = GCNConv(dim_in, dim_h)
    self.gcn2 = GCNConv(dim_h, dim_out)
    self.optimizer = torch.optim.Adam(self.parameters(),
                                      lr=0.001,
                                      weight_decay=5e-4)

  def forward(self, x, edge_index):
    h = F.dropout(x, p=0.5, training=self.training)
    h = self.gcn1(h, edge_index)
    h = torch.relu(h)
    h = F.dropout(h, p=0.5, training=self.training)
    h = self.gcn2(h, edge_index)
    
    return h

# %% [markdown]
# ## SAGE

# %%
class GraphSAGE(torch.nn.Module):
    def __init__(self, in_dim, hidden_dim, out_dim):
        super().__init__()
        self.conv1 = SAGEConv(in_dim, hidden_dim)
        self.conv2 = SAGEConv(hidden_dim, out_dim)
        self.optimizer = torch.optim.Adam(self.parameters(),
                                      lr=0.001,
                                      weight_decay=5e-4)
    
    def forward(self, x, edge_index):
        h = F.dropout(x, p=0.5)
        h = self.conv1(h, edge_index)
        h = F.relu(h)
        h = F.dropout(h, p=0.5)
        h = self.conv2(h, edge_index)
       
        return h

# %% [markdown]
# ### Pruebas variando numero de epocas

# %%
# GAT

acc_gat = []
prom_acc_gat = []
dev_values_gat = []
num_epochs_gat = []

#GCN

acc_gcn = []
prom_acc_gcn = []
dev_values_gcn = []
num_epochs_gcn = []

#SAGE

acc_sage = []
prom_acc_sage = []
dev_values_sage = []
num_epochs_sage = []

# %%
test_i = 1
val_j = 2

list_graph = []

for j in range(10):
  print(f"\n valor de i: {test_i}, valor de j: {val_j}")

  Idx_train, Idx_test, Idx_val = CrossVal(df, test_i, val_j)

  mini = X_tensor[Idx_train].min()
  maxi = X_tensor[Idx_train].max()
  X_tensor_norm = (X_tensor - mini) / (maxi - mini)

  data = graph(X_tensor_norm, Y_tensor, Idx_train, Idx_test, Idx_val, 5)

  list_graph.append(data)

  test_i = (test_i + 1)%11
  val_j = (val_j + 1)%11    
  if val_j==0:
    val_j = 1
# Out:
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1

# %%
for i in range(30,2030,100):
  test_i = 1
  val_j = 2

  for k in range(10):
#==========================GAT===============================================
      
      gat = GAT(128, 20, 10).to(device)
      train(gat, list_graph[k], epoch = i)
      acc_gat.append(test(gat, data, data.test_mask))

#==========================GCN===============================================  

      
      gcn = GCN(128, 20, 10).to(device).to(device)
      train(gcn, list_graph[k], epoch = i)
      acc_gcn.append(test(gcn, data, data.test_mask))

#==========================SAGE=============================================== 

      
      g_sage = GraphSAGE(128, 20, 10).to(device)
      train(g_sage, list_graph[k], epoch = i)
      acc_sage.append(test(g_sage, data, data.test_mask))

#==========================GAT===============================================

  prom_acc_gat.append(np.mean(acc_gat))
  dev_values_gat.append(np.std(acc_gat))
  num_epochs_gat.append(i)

#==========================GCN===============================================  

  prom_acc_gcn.append(np.mean(acc_gcn))
  dev_values_gcn.append(np.std(acc_gcn))
  num_epochs_gcn.append(i)

#==========================SAGE===============================================  

  prom_acc_sage.append(np.mean(acc_sage))
  dev_values_sage.append(np.std(acc_sage))
  num_epochs_sage.append(i)

  print(f"GAT\n accuracy mean: {np.mean(acc_gat)*100:.2f}% | standard deviation: {np.std(acc_gat):.2f} | epochs: {i}\n"
        f"GCN\n accuracy mean: {np.mean(acc_gcn)*100:.2f}% | standard deviation: {np.std(acc_gcn):.2f} | epochs: {i}\n"
        f"SAGE\n accuracy mean: {np.mean(acc_sage)*100:.2f}% | standard deviation: {np.std(acc_sage):.2f} | epochs: {i}\n\n"
        f"==============================================================================================================")
# Out:
# GAT
#  accuracy mean: 74.50% | standard deviation: 0.01 | epochs: 30
# GCN
#  accuracy mean: 36.80% | standard deviation: 0.07 | epochs: 30
# SAGE
#  accuracy mean: 33.16% | standard deviation: 0.03 | epochs: 30
#
# ==============================================================================================================
# GAT
#  accuracy mean: 79.66% | standard deviation: 0.06 | epochs: 130
# GCN
#  accuracy mean: 54.10% | standard deviation: 0.18 | epochs: 130
# SAGE
#  accuracy mean: 50.02% | standard deviation: 0.17 | epochs: 130
#
# ==============================================================================================================
# GAT
#  accuracy mean: 82.56% | standard deviation: 0.08 | epochs: 230
# GCN
#  accuracy mean: 61.54% | standard deviation: 0.18 | epochs: 230
# SAGE
#  accuracy mean: 57.73% | standard deviation: 0.18 | epochs: 230
#
# ==============================================================================================================
# GAT
#  accuracy mean: 84.64% | standard deviation: 0.08 | epochs: 330
# GCN
#  accuracy mean: 66.54% | standard deviation: 0.18 | epochs: 330
# SAGE
#  accuracy mean: 62.18% | standard deviation: 0.17 | epochs: 330
#
# ==============================================================================================================
# GAT
#  accuracy mean: 86.21% | standard deviation: 0.09 | epochs: 430
# GCN
#  accuracy mean: 70.14% | standard deviation: 0.18 | epochs: 430
# SAGE
#  accuracy mean: 65.24% | standard deviation: 0.17 | epochs: 430
#
# ==============================================================================================================
# GAT
#  accuracy mean: 87.28% | standard deviation: 0.09 | epochs: 530
# GCN
#  accuracy mean: 72.76% | standard deviation: 0.17 | epochs: 530
# SAGE
#  accuracy mean: 67.43% | standard deviation: 0.16 | epochs: 530
#
# ==============================================================================================================
# GAT
#  accuracy mean: 88.14% | standard deviation: 0.09 | epochs: 630
# GCN
#  accuracy mean: 74.79% | standard deviation: 0.17 | epochs: 630
# SAGE
#  accuracy mean: 69.11% | standard deviation: 0.16 | epochs: 630
#
# ==============================================================================================================
# GAT
#  accuracy mean: 88.84% | standard deviation: 0.09 | epochs: 730
# GCN
#  accuracy mean: 76.36% | standard deviation: 0.17 | epochs: 730
# SAGE
#  accuracy mean: 70.58% | standard deviation: 0.15 | epochs: 730
#
# ==============================================================================================================
# GAT
#  accuracy mean: 89.38% | standard deviation: 0.09 | epochs: 830
# GCN
#  accuracy mean: 77.62% | standard deviation: 0.16 | epochs: 830
# SAGE
#  accuracy mean: 71.66% | standard deviation: 0.15 | epochs: 830
#
# ==============================================================================================================
# GAT
#  accuracy mean: 89.84% | standard deviation: 0.09 | epochs: 930
# GCN
#  accuracy mean: 78.74% | standard deviation: 0.16 | epochs: 930
# SAGE
#  accuracy mean: 72.52% | standard deviation: 0.14 | epochs: 930
#
# ==============================================================================================================
# GAT
#  accuracy mean: 90.24% | standard deviation: 0.09 | epochs: 1030
# GCN
#  accuracy mean: 79.64% | standard deviation: 0.16 | epochs: 1030
# SAGE
#  accuracy mean: 73.29% | standard deviation: 0.14 | epochs: 1030
#
# ==============================================================================================================
# GAT
#  accuracy mean: 90.58% | standard deviation: 0.09 | epochs: 1130
# GCN
#  accuracy mean: 80.41% | standard deviation: 0.15 | epochs: 1130
# SAGE
#  accuracy mean: 73.92% | standard deviation: 0.14 | epochs: 1130
#
# ==============================================================================================================
# GAT
#  accuracy mean: 90.88% | standard deviation: 0.09 | epochs: 1230
# GCN
#  accuracy mean: 81.19% | standard deviation: 0.15 | epochs: 1230
# SAGE
#  accuracy mean: 74.45% | standard deviation: 0.13 | epochs: 1230
#
# ==============================================================================================================
# GAT
#  accuracy mean: 91.16% | standard deviation: 0.09 | epochs: 1330
# GCN
#  accuracy mean: 81.83% | standard deviation: 0.15 | epochs: 1330
# SAGE
#  accuracy mean: 74.95% | standard deviation: 0.13 | epochs: 1330
#
# ==============================================================================================================
# GAT
#  accuracy mean: 91.37% | standard deviation: 0.09 | epochs: 1430
# GCN
#  accuracy mean: 82.39% | standard deviation: 0.15 | epochs: 1430
# SAGE
#  accuracy mean: 75.31% | standard deviation: 0.13 | epochs: 1430
#
# ==============================================================================================================
# GAT
#  accuracy mean: 91.57% | standard deviation: 0.09 | epochs: 1530
# GCN
#  accuracy mean: 82.89% | standard deviation: 0.14 | epochs: 1530
# SAGE
#  accuracy mean: 75.70% | standard deviation: 0.12 | epochs: 1530
#
# ==============================================================================================================
# GAT
#  accuracy mean: 91.74% | standard deviation: 0.09 | epochs: 1630
# GCN
#  accuracy mean: 83.33% | standard deviation: 0.14 | epochs: 1630
# SAGE
#  accuracy mean: 76.04% | standard deviation: 0.12 | epochs: 1630
#
# ==============================================================================================================
# GAT
#  accuracy mean: 91.88% | standard deviation: 0.09 | epochs: 1730
# GCN
#  accuracy mean: 83.73% | standard deviation: 0.14 | epochs: 1730
# SAGE
#  accuracy mean: 76.28% | standard deviation: 0.12 | epochs: 1730
#
# ==============================================================================================================
# GAT
#  accuracy mean: 92.00% | standard deviation: 0.09 | epochs: 1830
# GCN
#  accuracy mean: 84.09% | standard deviation: 0.14 | epochs: 1830
# SAGE
#  accuracy mean: 76.55% | standard deviation: 0.12 | epochs: 1830
#
# ==============================================================================================================
# GAT
#  accuracy mean: 92.14% | standard deviation: 0.09 | epochs: 1930
# GCN
#  accuracy mean: 84.44% | standard deviation: 0.14 | epochs: 1930
# SAGE
#  accuracy mean: 76.78% | standard deviation: 0.11 | epochs: 1930
#
# ==============================================================================================================

# %%
plt.title('Vggish-GAT-epochs')
plt.errorbar(num_epochs_gat, prom_acc_gat,  yerr=dev_values_gat, fmt="o", capsize=3, ecolor="red")
plt.xlabel('Epochs')
plt.ylabel('accuracy-mean')

plt.savefig("Vggish-GAT-epochs.tiff", dpi = 300)

plt.show()

# %%
plt.title('Vggish-GCN-epochs')
plt.errorbar(num_epochs_gcn, prom_acc_gcn,  yerr=dev_values_gcn, fmt="o", capsize=3, ecolor="red")
plt.xlabel('Epochs')
plt.ylabel('accuracy-mean')

plt.savefig("Vggish-GCN-epochs.tiff", dpi = 300)

plt.show()

# %%
plt.title('Vggish-SAGE-epochs')
plt.errorbar(num_epochs_sage, prom_acc_sage,  yerr=dev_values_sage, fmt="o", capsize=3, ecolor="red")
plt.xlabel('Epochs')
plt.ylabel('accuracy-mean')

plt.savefig("Vggish-SAGE-epochs.tiff", dpi = 300)

plt.show()

# %% [markdown]
# ### Prueba variando numero de K vecinos

# %%
# GAT

acc_gat = []
K_values_gat = []
prom_acc_gat = []
dev_values_gat = []


#GCN

acc_gcn = []
K_values_gcn = []
prom_acc_gcn = []
dev_values_gcn = []

#SAGE

acc_sage = []
K_values_sage = []
prom_acc_sage = []
dev_values_sage = []

tiempo_graph = []

# %%
for j in range(5,101,5):
  test_i = 1
  val_j = 2

  for k in range(10):
      print(f"\n valor de i: {test_i}, valor de j: {val_j}")

      Idx_train, Idx_test, Idx_val = CrossVal(df, test_i, val_j)

      mini = X_tensor[Idx_train].min()
      maxi = X_tensor[Idx_train].max()
      X_tensor_norm = (X_tensor - mini) / (maxi - mini)

      start = time.time()
      data = graph(X_tensor_norm, Y_tensor, Idx_train, Idx_test, Idx_val, j)
      end = time.time()
#==========================GAT===============================================
      
      gat = GAT(128, 20, 10).to(device)
      train(gat, data, epoch = 50)
      acc_gat.append(test(gat, data, data.test_mask))

#==========================GCN===============================================  

      
      gcn = GCN(128, 20, 10).to(device).to(device)
      train(gcn, data, epoch = 50)
      acc_gcn.append(test(gcn, data, data.test_mask))

#==========================SAGE=============================================== 

      
      g_sage = GraphSAGE(128, 20, 10).to(device)
      train(g_sage, data, epoch = 50)
      acc_sage.append(test(g_sage, data, data.test_mask))


      test_i = (test_i + 1)%11
      val_j = (val_j + 1)%11    
      if val_j==0:
        val_j = 1

#==========================GAT===============================================

  K_values_gat.append(j)
  prom_acc_gat.append(np.mean(acc_gat))
  dev_values_gat.append(np.std(acc_gat))
  

#==========================GCN===============================================  

  K_values_gcn.append(j)
  prom_acc_gcn.append(np.mean(acc_gcn))
  dev_values_gcn.append(np.std(acc_gcn))

#==========================SAGE===============================================  

  K_values_sage.append(j)
  prom_acc_sage.append(np.mean(acc_sage))
  dev_values_sage.append(np.std(acc_sage))

  tiempo_graph.append(end - start)

  print(f"GAT\n accuracy mean: {np.mean(acc_gat)*100:.2f}% | standard deviation: {np.std(acc_gat):.2f} | Valor de K: {j}| tiempo: {(end - start):.2f} seg\n"
        f"GCN\n accuracy mean: {np.mean(acc_gcn)*100:.2f}% | standard deviation: {np.std(acc_gcn):.2f} | Valor de K: {j}| tiempo: {(end - start):.2f} seg\n"
        f"SAGE\n accuracy mean: {np.mean(acc_sage)*100:.2f}% | standard deviation: {np.std(acc_sage):.2f} | Valor de K: {j}| tiempo: {(end - start):.2f} seg\n\n"
        f"==============================================================================================================")
# Out:
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 69.40% | standard deviation: 0.04 | Valor de K: 5| tiempo: 2.85 seg
# GCN
#  accuracy mean: 49.56% | standard deviation: 0.06 | Valor de K: 5| tiempo: 2.85 seg
# SAGE
#  accuracy mean: 42.56% | standard deviation: 0.05 | Valor de K: 5| tiempo: 2.85 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 69.05% | standard deviation: 0.04 | Valor de K: 10| tiempo: 2.92 seg
# GCN
#  accuracy mean: 47.68% | standard deviation: 0.07 | Valor de K: 10| tiempo: 2.92 seg
# SAGE
#  accuracy mean: 43.60% | standard deviation: 0.05 | Valor de K: 10| tiempo: 2.92 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 68.51% | standard deviation: 0.05 | Valor de K: 15| tiempo: 3.02 seg
# GCN
#  accuracy mean: 46.77% | standard deviation: 0.08 | Valor de K: 15| tiempo: 3.02 seg
# SAGE
#  accuracy mean: 44.26% | standard deviation: 0.05 | Valor de K: 15| tiempo: 3.02 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 68.01% | standard deviation: 0.05 | Valor de K: 20| tiempo: 3.01 seg
# GCN
#  accuracy mean: 46.12% | standard deviation: 0.08 | Valor de K: 20| tiempo: 3.01 seg
# SAGE
#  accuracy mean: 44.42% | standard deviation: 0.05 | Valor de K: 20| tiempo: 3.01 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 67.60% | standard deviation: 0.05 | Valor de K: 25| tiempo: 3.04 seg
# GCN
#  accuracy mean: 45.80% | standard deviation: 0.08 | Valor de K: 25| tiempo: 3.04 seg
# SAGE
#  accuracy mean: 44.37% | standard deviation: 0.05 | Valor de K: 25| tiempo: 3.04 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 67.07% | standard deviation: 0.05 | Valor de K: 30| tiempo: 3.12 seg
# GCN
#  accuracy mean: 45.88% | standard deviation: 0.08 | Valor de K: 30| tiempo: 3.12 seg
# SAGE
#  accuracy mean: 44.37% | standard deviation: 0.05 | Valor de K: 30| tiempo: 3.12 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 66.82% | standard deviation: 0.05 | Valor de K: 35| tiempo: 3.09 seg
# GCN
#  accuracy mean: 45.92% | standard deviation: 0.10 | Valor de K: 35| tiempo: 3.09 seg
# SAGE
#  accuracy mean: 44.66% | standard deviation: 0.05 | Valor de K: 35| tiempo: 3.09 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 66.42% | standard deviation: 0.06 | Valor de K: 40| tiempo: 3.16 seg
# GCN
#  accuracy mean: 45.59% | standard deviation: 0.10 | Valor de K: 40| tiempo: 3.16 seg
# SAGE
#  accuracy mean: 44.32% | standard deviation: 0.05 | Valor de K: 40| tiempo: 3.16 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 66.10% | standard deviation: 0.06 | Valor de K: 45| tiempo: 3.14 seg
# GCN
#  accuracy mean: 45.08% | standard deviation: 0.10 | Valor de K: 45| tiempo: 3.14 seg
# SAGE
#  accuracy mean: 44.21% | standard deviation: 0.05 | Valor de K: 45| tiempo: 3.14 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 65.88% | standard deviation: 0.06 | Valor de K: 50| tiempo: 3.26 seg
# GCN
#  accuracy mean: 44.80% | standard deviation: 0.10 | Valor de K: 50| tiempo: 3.26 seg
# SAGE
#  accuracy mean: 44.26% | standard deviation: 0.05 | Valor de K: 50| tiempo: 3.26 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 65.62% | standard deviation: 0.06 | Valor de K: 55| tiempo: 3.13 seg
# GCN
#  accuracy mean: 44.45% | standard deviation: 0.09 | Valor de K: 55| tiempo: 3.13 seg
# SAGE
#  accuracy mean: 44.00% | standard deviation: 0.05 | Valor de K: 55| tiempo: 3.13 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 65.34% | standard deviation: 0.06 | Valor de K: 60| tiempo: 3.17 seg
# GCN
#  accuracy mean: 44.79% | standard deviation: 0.09 | Valor de K: 60| tiempo: 3.17 seg
# SAGE
#  accuracy mean: 43.99% | standard deviation: 0.05 | Valor de K: 60| tiempo: 3.17 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 65.07% | standard deviation: 0.06 | Valor de K: 65| tiempo: 3.17 seg
# GCN
#  accuracy mean: 44.37% | standard deviation: 0.10 | Valor de K: 65| tiempo: 3.17 seg
# SAGE
#  accuracy mean: 43.92% | standard deviation: 0.05 | Valor de K: 65| tiempo: 3.17 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 64.76% | standard deviation: 0.06 | Valor de K: 70| tiempo: 3.20 seg
# GCN
#  accuracy mean: 44.40% | standard deviation: 0.09 | Valor de K: 70| tiempo: 3.20 seg
# SAGE
#  accuracy mean: 43.86% | standard deviation: 0.05 | Valor de K: 70| tiempo: 3.20 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 64.46% | standard deviation: 0.06 | Valor de K: 75| tiempo: 3.24 seg
# GCN
#  accuracy mean: 43.87% | standard deviation: 0.10 | Valor de K: 75| tiempo: 3.24 seg
# SAGE
#  accuracy mean: 43.77% | standard deviation: 0.05 | Valor de K: 75| tiempo: 3.24 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 64.20% | standard deviation: 0.06 | Valor de K: 80| tiempo: 3.20 seg
# GCN
#  accuracy mean: 43.84% | standard deviation: 0.10 | Valor de K: 80| tiempo: 3.20 seg
# SAGE
#  accuracy mean: 43.80% | standard deviation: 0.05 | Valor de K: 80| tiempo: 3.20 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 63.87% | standard deviation: 0.06 | Valor de K: 85| tiempo: 3.39 seg
# GCN
#  accuracy mean: 43.59% | standard deviation: 0.10 | Valor de K: 85| tiempo: 3.39 seg
# SAGE
#  accuracy mean: 43.67% | standard deviation: 0.05 | Valor de K: 85| tiempo: 3.39 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 63.65% | standard deviation: 0.06 | Valor de K: 90| tiempo: 3.20 seg
# GCN
#  accuracy mean: 43.55% | standard deviation: 0.10 | Valor de K: 90| tiempo: 3.20 seg
# SAGE
#  accuracy mean: 43.54% | standard deviation: 0.05 | Valor de K: 90| tiempo: 3.20 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 63.49% | standard deviation: 0.06 | Valor de K: 95| tiempo: 3.32 seg
# GCN
#  accuracy mean: 43.43% | standard deviation: 0.10 | Valor de K: 95| tiempo: 3.32 seg
# SAGE
#  accuracy mean: 43.56% | standard deviation: 0.05 | Valor de K: 95| tiempo: 3.32 seg
#
# ==============================================================================================================
#
#  valor de i: 1, valor de j: 2
#
#  valor de i: 2, valor de j: 3
#
#  valor de i: 3, valor de j: 4
#
#  valor de i: 4, valor de j: 5
#
#  valor de i: 5, valor de j: 6
#
#  valor de i: 6, valor de j: 7
#
#  valor de i: 7, valor de j: 8
#
#  valor de i: 8, valor de j: 9
#
#  valor de i: 9, valor de j: 10
#
#  valor de i: 10, valor de j: 1
# GAT
#  accuracy mean: 63.30% | standard deviation: 0.07 | Valor de K: 100| tiempo: 3.27 seg
# GCN
#  accuracy mean: 43.34% | standard deviation: 0.10 | Valor de K: 100| tiempo: 3.27 seg
# SAGE
#  accuracy mean: 43.61% | standard deviation: 0.05 | Valor de K: 100| tiempo: 3.27 seg
#
# ==============================================================================================================

# %%
plt.title('Vggish-GAT-K')
plt.errorbar(K_values_gat, prom_acc_gat,  yerr=dev_values_gat, fmt="o", capsize=3, ecolor="red")
plt.xlabel('K')
plt.ylabel('accuracy-mean')

plt.savefig("Vggish_GAT_K.tiff", dpi = 300)

plt.show()

# %%
plt.title('Vggish-GCN-K')
plt.errorbar(K_values_gcn, prom_acc_gcn,  yerr=dev_values_gcn, fmt="o", capsize=3, ecolor="red")
plt.xlabel('K')
plt.ylabel('accuracy-mean')

plt.savefig("Vggish_GCN_K.tiff", dpi = 300)

plt.show()

# %%
plt.title('Vggish-SAGE-K')
plt.errorbar(K_values_sage, prom_acc_sage,  yerr=dev_values_sage, fmt="o", capsize=3, ecolor="red")
plt.xlabel('K')
plt.ylabel('accuracy-mean')

plt.savefig("Vggish_SAGE_K.tiff", dpi = 300)

plt.show()

# %%
plt.title('K-tiempo (Vggish)')
plt.plot(K_values_gat,tiempo_graph,'o')
plt.xlabel('K')
plt.ylabel('Time')
plt.savefig("Vggish_Tiempo.tiff", dpi = 300)
plt.show()
