# %%
# !pip install panns_inference
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import librosa
import torch

import panns_inference
import pandas as pd
import numpy as np


from tqdm import tqdm
from panns_inference import AudioTagging, SoundEventDetection, labels

# %%
df = pd.read_csv("/content/drive/MyDrive/Teoría de grafos/urban/UrbanSound8K.csv")
df
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 0       100032-3-0-0.wav  100032    0.000000    0.317551         1     5
# 1     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 2     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 3     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 4     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8727     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8728     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8729     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8730     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8731     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           3          dog_bark
# ...

# %%
df = df[(df.end - df.start) >= 1]
df.reset_index(drop=True, inplace=True)
df
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 0     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 1     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 2     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 3     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# 4     100263-2-0-143.wav  100263   71.500000   75.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8271     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8272     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8273     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8274     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8275     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           2  children_playing
# ...

# %%
path = "/content/drive/MyDrive/Teoría de grafos/urban/"

def embeddingsLabels(df):

    y = []
    emb = []

    for index, row in tqdm(df.iterrows(), total = df.shape[0]):
        ruta = f"{path}fold{row.fold}/{row.slice_file_name}"
        
        
        audio, sr = librosa.load(ruta)
        audio = audio[None, :]

        at = AudioTagging(checkpoint_path=None, device='cuda')
        (clipwise_output, embedding) = at.inference(audio)

        embedding = torch.tensor(embedding)
        
        emb.append(embedding)
        y.append(row["classID"])

        #if index == 9:
         # break


    X = torch.cat(emb,0)
    y = torch.tensor(y)

# %%
X_tensor ,y_tensor = embeddingsLabels(df)
